# %% [markdown]
# ![Movie popcorn on red background](redpopcorn.jpg)

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry. Our friend has also been brushing up on their Python skills and has taken a first crack at a CSV file containing Netflix data. They believe that the average duration of movies has been declining. Using your friends initial research, you'll delve into the Netflix data to see if you can determine whether movie lengths are actually getting shorter and explain some of the contributing factors, if any.
#
# You have been supplied with the dataset `netflix_data.csv` , along with the following table detailing the column names and descriptions. This data does contain null values and some outliers, but handling these is out of scope for the project. Feel free to experiment after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Start coding!

# %% [markdown]
# 1. Load and inspect the Netflix data

# %%
netflix_df = pd.read_csv("netflix_data.csv", index_col = 0)
netflix_df[0:5]
# Out:
#             type  ...             genre
# show_id           ...
# s1       TV Show  ...  International TV
# s2         Movie  ...            Dramas
# s3         Movie  ...     Horror Movies
# s4         Movie  ...            Action
# s5         Movie  ...            Dramas
#
# [5 rows x 10 columns]

# %% [markdown]
# 2. Subset the DataFrame for "Movies"

# %%
netflix_subset = netflix_df[netflix_df["type"] == "Movie"]
netflix_subset[0:5]
# Out:
#           type  ...          genre
# show_id         ...
# s2       Movie  ...         Dramas
# s3       Movie  ...  Horror Movies
# s4       Movie  ...         Action
# s5       Movie  ...         Dramas
# s7       Movie  ...  Horror Movies
#
# [5 rows x 10 columns]

# %% [markdown]
# 3. Subset the columns of the new DataFrame

# %%
netflix_movies = netflix_subset[["title", "country", "genre", "release_year", "duration"]]
netflix_movies[0:5]
# Out:
#          title        country          genre  release_year  duration
# show_id
# s2        7:19         Mexico         Dramas          2016        93
# s3       23:59      Singapore  Horror Movies          2011        78
# s4           9  United States         Action          2009        80
# s5          21  United States         Dramas          2008       123
# s7         122          Egypt  Horror Movies          2019        95

# %% [markdown]
# 4. Filter the DataFrame by Movie duration

# %%
short_movies = netflix_movies[netflix_movies['duration'] < 60]
short_movies[0:20]
# Out:
#                                                      title  ... duration
# show_id                                                     ...
# s36                                              #Rucker50  ...       56
# s56                    100 Things to do Before High School  ...       44
# s68      13TH: A Conversation with Oprah Winfrey & Ava ...  ...       37
# s102                                     3 Seconds Divorce  ...       53
# s147                                        A 3 Minute Hug  ...       28
# s163     A Christmas Special: Miraculous: Tales of Lady...  ...       22
# s172                            A Family Reunion Christmas  ...       29
# s178                       A Go! Go! Cory Carson Christmas  ...       22
# s179                       A Go! Go! Cory Carson Halloween  ...       22
# s180                     A Go! Go! Cory Carson Summer Camp  ...       21
# s182                A Grand Night In: The Story of Aardman  ...       59
# s201                               A Love Song for Latasha  ...       20
# s221                            A Russell Peters Christmas  ...       44
# s234                                 A StoryBots Christmas  ...       26
# s238                                A Tale of Two Kitchens  ...       30
# s243                               A Trash Truck Christmas  ...       28
# s248                               A Very Murray Christmas  ...       57
# s286                                  Abominable Christmas  ...       44
# s296                                    Across Grace Alley  ...       24
# s306                   Adam Devine: Best Time of Our Lives  ...       59
#
# [20 rows x 5 columns]

# %% [markdown]
# 5. Assign colors to movie genres

# %%
colors = []

for lab, row in netflix_movies.iterrows():
    if row['genre'] == "Children":
        colors.append("Purple")
    elif row['genre'] == "Documentaries":
        colors.append("Blue")
    elif row['genre'] == "Stand-Up":
        colors.append("Orange")
    else:
        colors.append("Green")
        
colors
# Out:
# ['Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Blue',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Green',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Blue',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Purple',
#  'Green',
#  'Orange',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Orange',
#  'Green',
#  'Green',
#  'Orange',
#  'Green',
#  'Orange',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Green',
#  'Blue',
#  'Blue',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Orange',
#  'Blue',
#  'Green',
#  'Orange',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Orange',
#  'Orange',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Purple',
#  'Purple',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Purple',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Purple',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Blue',
#  'Blue',
#  'Blue',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Green',
#  'Green',
#  'Blue',
#  'Orange',
#  'Orange',
#  'Blue',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Orange',
#  'Orange',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Purple',
#  'Green',
#  'Green',
#  'Orange',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Blue',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Purple',
#  'Green',
#  'Purple',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Blue',
#  'Blue',
#  'Blue',
#  'Green',
#  'Blue',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Green',
#  'Orange',
#  'Blue',
#  'Blue',
#  'Purple',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Purple',
#  'Green',
#  'Blue',
#  'Purple',
#  'Blue',
#  'Purple',
#  'Blue',
#  'Blue',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Blue',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Blue',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Blue',
#  'Green',
#  'Orange',
#  'Blue',
#  'Purple',
#  'Blue',
#  'Purple',
#  'Green',
#  'Green',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Blue',
#  'Blue',
#  'Blue',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Blue',
#  'Orange',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Purple',
#  'Purple',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Purple',
#  'Blue',
#  'Green',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Orange',
#  'Orange',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Purple',
#  'Blue',
#  'Green',
#  'Orange',
#  'Green',
#  'Blue',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Orange',
#  'Orange',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Purple',
#  'Green',
#  'Purple',
#  'Green',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Purple',
#  'Green',
#  'Orange',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Green',
#  'Orange',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Purple',
#  'Purple',
#  'Green',
#  'Green',
#  'Purple',
#  'Purple',
#  'Purple',
#  ...]

# %% [markdown]
# 6. Plot the movie duration by year using the genre colors created

# %%
fig = plt.figure(figsize=(12,8))
plt.scatter(netflix_movies["release_year"], netflix_movies["duration"], c=colors)
plt.xlabel("Release year")
plt.ylabel("Duration (min)")
plt.title("Movie Duration by Year of Release")
# Out:
# Text(0.5, 1.0, 'Movie Duration by Year of Release')

# %% [markdown]
# 7. Answer

# %%
answer = "no"
answer
# Out:
# 'no'
